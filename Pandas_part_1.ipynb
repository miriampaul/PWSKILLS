# %%
import pandas as pd # Pandas library Available by default

# %%
pd.read_csv('financial.csv')
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2021                     Level 1                99999
# 1      2021                     Level 1                99999
# 2      2021                     Level 1                99999
# 3      2021                     Level 1                99999
# 4      2021                     Level 1                99999
# ...     ...                         ...                  ...
# 41710  2013                     Level 3                 ZZ11
# 41711  2013                     Level 3                 ZZ11
# 41712  2013                     Level 3                 ZZ11
# 41713  2013                     Level 3                 ZZ11
# 41714  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
#if first row does not have header as column name then use header=None

# %%
df=pd.read_csv('financial.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['Year', 'Industry_aggregation_NZSIOC', 'Industry_code_NZSIOC',
#        'Industry_name_NZSIOC', 'Units', 'Variable_code', 'Variable_name',
#        'Variable_category', 'Value', 'Industry_code_ANZSIC06'],
#       dtype='object')

# %%
list(df.columns)
# Out:
# ['Year',
#  'Industry_aggregation_NZSIOC',
#  'Industry_code_NZSIOC',
#  'Industry_name_NZSIOC',
#  'Units',
#  'Variable_code',
#  'Variable_name',
#  'Variable_category',
#  'Value',
#  'Industry_code_ANZSIC06']

# %%
df.head()# gives first 5 records
# Out:
#    Year Industry_aggregation_NZSIOC Industry_code_NZSIOC Industry_name_NZSIOC  \
# 0  2021                     Level 1                99999       All industries
# 1  2021                     Level 1                99999       All industries
# 2  2021                     Level 1                99999       All industries
# 3  2021                     Level 1                99999       All industries
# 4  2021                     Level 1                99999       All industries
#
#                 Units Variable_code  \
# 0  Dollars (millions)           H01
# 1  Dollars (millions)           H04
# 2  Dollars (millions)           H05
# 3  Dollars (millions)           H07
# 4  Dollars (millions)           H08
#
#                                      Variable_name      Variable_category  \
# 0                                     Total income  Financial performance
# 1  Sales, government funding, grants and subsidies  Financial performance
# ...

# %%
df.head(3)#first 3 records
# Out:
#    Year Industry_aggregation_NZSIOC Industry_code_NZSIOC Industry_name_NZSIOC  \
# 0  2021                     Level 1                99999       All industries
# 1  2021                     Level 1                99999       All industries
# 2  2021                     Level 1                99999       All industries
#
#                 Units Variable_code  \
# 0  Dollars (millions)           H01
# 1  Dollars (millions)           H04
# 2  Dollars (millions)           H05
#
#                                      Variable_name      Variable_category  \
# 0                                     Total income  Financial performance
# 1  Sales, government funding, grants and subsidies  Financial performance
# 2                Interest, dividends and donations  Financial performance
#
#      Value                             Industry_code_ANZSIC06
# 0  757,504  ANZSIC06 divisions A-S (excluding classes K633...
# 1  674,890  ANZSIC06 divisions A-S (excluding classes K633...
# ...

# %%
df.tail()#Last 3 records
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 41710  2013                     Level 3                 ZZ11
# 41711  2013                     Level 3                 ZZ11
# 41712  2013                     Level 3                 ZZ11
# 41713  2013                     Level 3                 ZZ11
# 41714  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC       Units Variable_code  \
# 41710  Food product manufacturing  Percentage           H37
# 41711  Food product manufacturing  Percentage           H38
# 41712  Food product manufacturing  Percentage           H39
# 41713  Food product manufacturing  Percentage           H40
# 41714  Food product manufacturing  Percentage           H41
#
#                              Variable_name Variable_category Value  \
# 41710                          Quick ratio  Financial ratios    52
# 41711  Margin on sales of goods for resale  Financial ratios    40
# ...

# %%
df.dtypes
# Out:
# Year                            int64
# Industry_aggregation_NZSIOC    object
# Industry_code_NZSIOC           object
# Industry_name_NZSIOC           object
# Units                          object
# Variable_code                  object
# Variable_name                  object
# Variable_category              object
# Value                          object
# Industry_code_ANZSIC06         object
# dtype: object

# %%
df.columns
# Out:
# Index(['Year', 'Industry_aggregation_NZSIOC', 'Industry_code_NZSIOC',
#        'Industry_name_NZSIOC', 'Units', 'Variable_code', 'Variable_name',
#        'Variable_category', 'Value', 'Industry_code_ANZSIC06'],
#       dtype='object')

# %%
df['Year'] # selects only one column and gives the details of it
# Out:
# 0        2021
# 1        2021
# 2        2021
# 3        2021
# 4        2021
#          ...
# 41710    2013
# 41711    2013
# 41712    2013
# 41713    2013
# 41714    2013
# Name: Year, Length: 41715, dtype: int64

# %%
type(df['Year'])
# Out:
# pandas.core.series.Series

# %%
list(df['Year'])
# Out:
# [2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
# ...

# %%
df.columns
# Out:
# Index(['Year', 'Industry_aggregation_NZSIOC', 'Industry_code_NZSIOC',
#        'Industry_name_NZSIOC', 'Units', 'Variable_code', 'Variable_name',
#        'Variable_category', 'Value', 'Industry_code_ANZSIC06'],
#       dtype='object')

# %%
df[['Year']]
# Out:
#        Year
# 0      2021
# 1      2021
# 2      2021
# 3      2021
# 4      2021
# ...     ...
# 41710  2013
# 41711  2013
# 41712  2013
# 41713  2013
# 41714  2013
#
# [41715 rows x 1 columns]

# %%
df.columns
# Out:
# Index(['Year', 'Industry_aggregation_NZSIOC', 'Industry_code_NZSIOC',
#        'Industry_name_NZSIOC', 'Units', 'Variable_code', 'Variable_name',
#        'Variable_category', 'Value', 'Industry_code_ANZSIC06'],
#       dtype='object')

# %%
df[['Year','Value']] # TO select multiple columns select inside a list []
# Out:
#        Year    Value
# 0      2021  757,504
# 1      2021  674,890
# 2      2021   49,593
# 3      2021   33,020
# 4      2021  654,404
# ...     ...      ...
# 41710  2013       52
# 41711  2013       40
# 41712  2013       12
# 41713  2013        5
# 41714  2013       46
#
# [41715 rows x 2 columns]

# %%
df1=pd.read_excel('excelfile.xls')

# %%
#multiple sheet sheet=''

# %%
df1.head()
# Out:
#    0 First Name  Last Name  Gender        Country  Age        Date    Id
# 0  1      Dulce      Abril  Female  United States   32  15/10/2017  1562
# 1  2       Mara  Hashimoto  Female  Great Britain   25  16/08/2016  1582
# 2  3     Philip       Gent    Male         France   36  21/05/2015  2587
# 3  4   Kathleen     Hanner  Female  United States   25  15/10/2017  3549
# 4  5    Nereida    Magwood  Female  United States   58  16/08/2016  2468

# %%
df1.tail()
# Out:
#    0 First Name Last Name  Gender        Country  Age        Date    Id
# 4  5    Nereida   Magwood  Female  United States   58  16/08/2016  2468
# 5  6     Gaston     Brumm    Male  United States   24  21/05/2015  2554
# 6  7       Etta      Hurn  Female  Great Britain   56  15/10/2017  3598
# 7  8    Earlean    Melgar  Female  United States   27  16/08/2016  2456
# 8  9   Vincenza   Weiland  Female  United States   40  21/05/2015  6548

# %%
df1.columns
# Out:
# Index([0, 'First Name', 'Last Name', 'Gender', 'Country', 'Age', 'Date', 'Id'], dtype='object')

# %%
df1[['First Name']]
# Out:
#   First Name
# 0      Dulce
# 1       Mara
# 2     Philip
# 3   Kathleen
# 4    Nereida
# 5     Gaston
# 6       Etta
# 7    Earlean
# 8   Vincenza

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df1.dtypes
# Out:
# 0              int64
# First Name    object
# Last Name     object
# Gender        object
# Country       object
# Age            int64
# Date          object
# Id             int64
# dtype: object

# %%
df1.tail(3)
# Out:
#    0 First Name Last Name  Gender        Country  Age        Date    Id
# 6  7       Etta      Hurn  Female  Great Britain   56  15/10/2017  3598
# 7  8    Earlean    Melgar  Female  United States   27  16/08/2016  2456
# 8  9   Vincenza   Weiland  Female  United States   40  21/05/2015  6548

# %%
df1.columns
# Out:
# Index([0, 'First Name', 'Last Name', 'Gender', 'Country', 'Age', 'Date', 'Id'], dtype='object')

# %%
df1.to_csv('titanic.csv', index=False)

# %%
df1
# Out:
#    0 First Name  Last Name  Gender        Country  Age        Date    Id
# 0  1      Dulce      Abril  Female  United States   32  15/10/2017  1562
# 1  2       Mara  Hashimoto  Female  Great Britain   25  16/08/2016  1582
# 2  3     Philip       Gent    Male         France   36  21/05/2015  2587
# 3  4   Kathleen     Hanner  Female  United States   25  15/10/2017  3549
# 4  5    Nereida    Magwood  Female  United States   58  16/08/2016  2468
# 5  6     Gaston      Brumm    Male  United States   24  21/05/2015  2554
# 6  7       Etta       Hurn  Female  Great Britain   56  15/10/2017  3598
# 7  8    Earlean     Melgar  Female  United States   27  16/08/2016  2456
# 8  9   Vincenza    Weiland  Female  United States   40  21/05/2015  6548

# %%
url=pd.read_html('https://en.wikipedia.org/wiki/Basketball')

# %%
type(url)
# Out:
# list

# %%
len(url)
# Out:
# 29

# %%
df4=url[0]

# %%
df4.head()
# Out:
#                                                    0  \
# 0  Vince Carter (blue) tries to make a layup shot...
# 1                             Highest governing body
# 2                                       First played
# 3                                    Characteristics
# 4                                            Contact
#
#                                                    1
# 0  Vince Carter (blue) tries to make a layup shot...
# 1                                               FIBA
# 2  December 21, 1891; 131 years agoSpringfield, M...
# 3                                    Characteristics
# 4                                            Limited

# %%
df4.columns
# Out:
# Int64Index([0, 1], dtype='int64')

# %%
df4.to_csv('players.csv', index=False)
